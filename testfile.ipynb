# %%
#user_choice = input('What do you choose? Type 0 for rock,1 for paper  or 2 for scissor:  ')

##basket = "rock paper scissors"

##basket.split()

#import random

#computer_choice = random.randint(0, 2)

#game_basket = [rock, paper, scissor]

#if user_choice >= 0 and user_choice <3:
    #print(game_basket[user_choice])
#    ##print(game_basket[computer_choice])
#else:
    #print("invalid choice")

# %%
#nums = range(100)

#list(nums)

#list(range(2,7))

#list(range(0,20,5))

#Tuples

#row = ("mawuli" , "portia")
#row_2 = ("Glen" , "Portia ")

#digits = [0,1,1,2,3,4,5,6,6,7,8,9]

#digits_set = set(digits)

#print(digits_set)

#odd = {1,3,5,7,9}

#even = digits_set - odd 
#even = digits_set | odd

#prime = set([2,3,5,7])

##print(prime_even)

#list1 = []

#list1.extend(["Zmija" , " Sifija " , " Zajchija"])
#list1.append("Marija")
#list1.sort()

#print(list1[0:2])

#ime = ("Filip" , " Mladenovski" , "30")
#ime2 = ("Marija " , " Mladenovska " ,"31")
#ime3 = ("Sofia" , "Mladenovska" , "10 mnth")

#people = []

#people.extend(ime)
#people.extend(ime2)
#people.extend(ime3)

#people.sort()

#print(people)





#List = ["Zajche " , " Marija" , " SOfija " , " Filip" , "Marija"]

#def most_freq(List):
   # r#eturn max(set(List), key = List.count)

#print(most_freq(List))



#book = '''
#True, and therefore women, being the weaker vessels, are ever thrust to
#the wall: therefore I will push Montague’s men from the wall, and
#thrust his maids to the wall.'''

#book_2 = '''See the line from a sufficient distance, and
#it straightens itself to the average tendency. Your genuine action
#will explain itself'''

#for letter in ['a', 'z' , 'u' , 'b ' , 'i']:
   # print(letter)

#names = ['matt' , 'jade' , 'glen']

#for name in names:
 #   print(name)

#names = ['marvin' , 'portia' , 'glen' , 'Azubi' , 'matt' , 'isaac' ]

#for index in range(len(names)):
    #print(f'Index {index}  ---> Value {names[index]}')


#for item , value in enumerate(names):
    #print(f'Index {index} --> Vaklue {value})

##numbers = [3,5,9,-1,3,1]

#result = 0

#for item in numbers:
    #if item < 0:
        #break
   #else:
#result += item
    ##       result += item      ==== uses what is called augmented assignment.it is similar to writing: result = result + item


#print(result)


#numbers = [3,5,9,-1,3,1]

#result = 0 

#or item in numbers:
   # if item < 0:
       # continue
    #else:
        #result += item

#print(result)

#n = 3

#while n > 0:
    #print(n)
    #n = n-1

#n = 3

#while True:
 #   print(n)
  #  n = n - 1
   # if n == 0:
    #    break

#

#kolegi =  ["Milda" , "Glen " , "Joseph " , "Maria"]
#riends = ["Zajche" , "Sofia" , "Batat" , "Zmija"]

#for name in kolegi + friends:
    ## print("Not Found")

#Case study

#products = ["Sankofa Foods","Jamestown Coffee","Bioko Chocolate","Blue Skies Ice Cream","Fair Afric Chocolate","Kawa Moka Coffee","Aphro Spirit" ,"Mensado Bissap","Voltic"]

#prices = [30,25,40,20,20,35,45,50,35]

#last_week = [2,3,5,8,4,4,6,2,9]







#aver_prices = sum(prices) / len(prices ) # quest 1

#Quest 2

#new_prices = []

#for item in prices:
#    item = (5 / 100) * item


#for item2 in prices:
#    item2 = item2 - item 
#    new_prices.append(item2)


#res = {}
#for key in products:
#    for value in new_prices:
#        res[key] = value
#        new_prices.remove(value)
#        break

#print(res)


#print(new_prices) 



# question 3  total revenue from the products


#total_revenue = [a * b for a,b in zip(prices , last_week)]
#print("New list with each product : " , total_revenue )
#print("Total Revenue : " , sum(total_revenue))

#question 4 calculate the average daily revenue generated from the prducts

#total_revenue_sum = sum(total_revenue)

#daily = total_revenue_sum / 7

#avg_daily = (total_revenue_sum / 9) / 7
#print("Daily revenue :" , daily ,  "Avg Daily:" , avg_daily)


#Sales and Operations planning project
# Out:
# >>>Production quantity month 1 - 0
# Production Quantity month 2 - 0
# >>>Production quantity month 3 -  100
# >>>Production Quantity month 4 -  400
# >>>Production Quantity month 5 -  100
