# %%
movie_db = {
"The Shawshank Redemption":{
"year": 1994, 
"director": "Frank Darabont",
"stars": ["Tim Robbins","Morgan Freeman","Bob Gunton"],
"genre":["Drama"],
"rating":9.3
},
"The Godfather":{
"year": 1972,
"director": "Francis Ford Coppola",
"stars":["Marlon Brando" ,"Al Pacino","James Caan"],
"genre":["Crime","Drama"],
"rating":9.2
},
"The Godfather: Part II":{
"year": 1974,
"director": "Francis Ford Coppola",
"stars":["Al Pacino","Robert De Niro","Robert Duvali"],
"genre":["Crime","Drama"],
"rating": 9.0
},
"The Dark Knight":{
"year": 2008,
"director":"Chrostopher Nolan",
"stars":["Christian Bale", "Heath Ledger","Aaron Echart"],
"genre":["Action","Crime","Drama"],
"rating":9.0
},
"12 Angry Men":{
"year":1957,
"director": "Sidney Lumet",
"stars":["Henry Fonda","Lee J. Cobb","Martin Balsam"],
"genre":["Drama"],
"rating":8.9
},
"Schindler's List":{
"year":1993,
"director":"Steven Spielberg",
"stars":["Liam Neeson","Ralph Fiennes","Ben Kingsley"],
"genre":["Bography","Drama","History"],
"rating":8.9
},
"The Lord of the Rings: The Return of the King":{
"year":2003,
"director":"Peter Jackson",
"stars":["Elijah Wood","Viggo Mortensen","Ian McKellen"],
"genre":["Action","Adventure","Drama"],
"rating":8.9
},
"Pulp Fiction":{
"year":2001,
"director": "Peter Jackson",
"stars":["Elijah Wood","Ian McKellen","Orlando Bloom"],
"genre":["Action","Adventure","Drama"],
"rating":8.9
},
"The Lord of the Rings : The Fellowship of the Ring":{
"year":2001,
"director":"Peter Jackson",
"stars":["Elijah Wood","Ian Mckellen","Orlando Bloom"],
"genre":["Action","Adventure","Drama"],
"rating":8.8
},
"Forest Gump":{
"year":1994,
"director":"Robert Zemeckis",
"stars":["Tom Hanks","Robin Wright","Gary Sinise"],
"genre":["Drama","Romance"],
"rating":8.8
},
"Inception":{
"year":2010,
"director":"Christopher Nolan",
"stars":["Leonardo DiCaprio","Joseph Gordon - Levvit ","Ellen Page"],
"genre":["Action","Adventure","Sci-Fi"],
"rating":8.8
},
}

#saearch_term = input("Enter a search term: ")
#search_criteria = input("Enter a search criteria (title,year,director,stars,genre)")
#another_search = input("Do you want to perform another search? (y/n): ")

movie_db["year"]["director"]["stars"],["genre"],["rating"]

#choice = movie_db[search_term]
# Out:
# year
# director
# stars
# genre
# rating
